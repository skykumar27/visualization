# %%
import pandas as pd

meteorites = pd.read_csv('Meteorite_Landings.csv',nrows=5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  year    reclat  \
# 0    Aachen    1    Valid           L5        21  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6       720  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4    107000  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6       780  Fell  1902 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import pandas as pd

meteorites = pd.read_csv('Meteorite_Landings.csv')
meteorites
# Out:
#                    name       id nametype     recclass  mass (g)   fall  \
# 0                Aachen      1.0    Valid           L5      21.0   Fell
# 1                Aarhus      2.0    Valid           H6     720.0   Fell
# 2                  Abee      6.0    Valid          EH4  107000.0   Fell
# 3              Acapulco     10.0    Valid  Acapulcoite    1914.0   Fell
# 4               Achiras    370.0    Valid           L6     780.0   Fell
# ...                 ...      ...      ...          ...       ...    ...
# 35987  Red Dry Lake 002  22539.0    Valid           H6      21.5  Found
# 35988  Red Dry Lake 003  22540.0    Valid           H6      94.0  Found
# 35989  Red Dry Lake 004  22541.0    Valid           H6      13.5  Found
# 35990  Red Dry Lake 005  22542.0    Valid           H6      12.0  Found
# 35991        Red Dry La      NaN      NaN          NaN       NaN    NaN
#
#          year    reclat    reclong             GeoLocation
# 0      1880.0  50.77500    6.08333       (50.775, 6.08333)
# 1      1951.0  56.18333   10.23333    (56.18333, 10.23333)
# 2      1952.0  54.21667 -113.00000      (54.21667, -113.0)
# 3      1976.0  16.88333  -99.90000       (16.88333, -99.9)
# 4      1902.0 -33.16667  -64.95000     (-33.16667, -64.95)
# ...       ...       ...        ...                     ...
# 35987  2001.0  35.65306 -114.02437  (35.65306, -114.02437)
# 35988  2001.0  35.64552 -114.03069  (35.64552, -114.03069)
# 35989  2001.0  35.64640 -114.02849   (35.6464, -114.02849)
# 35990  2001.0  35.64645 -114.02853  (35.64645, -114.02853)
# 35991     NaN       NaN        NaN                     NaN
#
# [35992 rows x 10 columns]

# %%
import requests

response = requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json',
                        params={'$limit':50_000})
if response.ok:
  payload =response.json()
else:
  print(f'Request was not successful and returned code:{response.status_code}')
  payload=None

# %%
import pandas as pd

df=pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
